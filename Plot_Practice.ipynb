# %%
# prerequisite package imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from solutions_biv import violinbox_solution_1

# %% [markdown]
# We'll continue to make use of the fuel economy dataset in this workspace.

# %%
fuel_econ = pd.read_csv('./data/fuel_econ.csv')
fuel_econ.head()
# Out:
#       id        make           model  year           VClass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
#
#                drive              trans          fuelType  cylinders  displ  \
# 0    All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# 1  Front-Wheel Drive  Automatic (AM-S6)  Premium Gasoline          4    2.0
# 2  Front-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 3    All-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 4  Front-Wheel Drive     Automatic (S6)  Regular Gasoline          4    2.4
#
#    pv2  pv4     city    UCity  highway  UHighway     comb  co2  feScore  \
# 0   79    0  16.4596  20.2988  22.5568   30.1798  18.7389  471        4
# 1   94    0  21.8706  26.9770  31.0367   42.4936  25.2227  349        6
# 2   94    0  17.4935  21.2000  26.5716   35.1000  20.6716  429        5
# 3   94    0  16.9415  20.5000  25.2190   33.5000  19.8774  446        5
# 4    0   95  24.7726  31.9796  35.5340   51.8816  28.6813  310        8
#
#    ghgScore
# 0         4
# 1         6
# 2         5
# 3         5
# 4         8

# %%
fuel_econ.dtypes
# Out:
# id             int64
# make          object
# model         object
# year           int64
# VClass        object
# drive         object
# trans         object
# fuelType      object
# cylinders      int64
# displ        float64
# pv2            int64
# pv4            int64
# city         float64
# UCity        float64
# highway      float64
# UHighway     float64
# comb         float64
# co2            int64
# feScore        int64
# ghgScore       int64
# dtype: object

# %% [markdown]
# ### Preparatory Step
# The cars in this dataset are categorized into one of five different vehicle classes based on size. Starting from the smallest, they are: `{Minicompact Cars, Subcompact Cars, Compact Cars, Midsize Cars, and Large Cars}`.
#
#
#
# ### **TO DO**:
# 1. What is the relationship between the size of a car and the size of its engine? The vehicle classes can be found in the `VClass` column, while the engine sizes are in the `displ` column (in liters).
#
# **Hint**: Make sure that the order of vehicle classes makes sense in your plot!

# %%
# YOUR CODE HERE
sedan_classes = ['Minicompact Cars', 'Subcompact Cars', 'Compact Cars', 'Midsize Cars', 'Large Cars']
vclass = pd.api.types.CategoricalDtype(categories = sedan_classes, ordered = True)
fuel_econ['VClass'] = fuel_econ['VClass'].astype(vclass)
base_color = sns.color_palette()[0]
sns.violinplot(data = fuel_econ, x = 'VClass', y = 'displ', color = base_color)
plt.xticks(rotation = 45)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text xticklabel objects>)

# %% [markdown]
# I used a violin plot to depict the data in this case; you might have chosen a box plot instead. One of the interesting things about the relationship between variables is that it isn't consistent. Compact cars tend to have smaller engine sizes than the minicompact and subcompact cars, even though those two vehicle sizes are smaller. The box plot would make it easier to see that the median displacement for the two smallest vehicle classes is greater than the third quartile of the compact car class.

# %%
plt.figure(figsize=[20,5])
base_color = sns.color_palette()[0]
plt.subplot(1,3,1)
ax1 = sns.violinplot(data = fuel_econ, x = 'VClass', y = 'displ', inner = None, color = base_color)
plt.xticks(rotation = 45)

#2nd plot

plt.subplot(1,3,2)
ax2 = sns.violinplot(data = fuel_econ, x = 'VClass', y = 'displ', inner = 'quartile', color = base_color)
plt.xticks(rotation = 90)

# 3rd plot

plt.subplot(1,3,3)
ax3 = sns.boxplot(data = fuel_econ, x = 'VClass', y = 'displ')
plt.xticks(rotation = 90)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text xticklabel objects>)

# %%
fuel_econ['fuelType'].value_counts()
# Out:
# Premium Gasoline     2302
# Regular Gasoline     1521
# Diesel                 80
# Midgrade Gasoline      23
# Natural Gas             3
# Name: fuelType, dtype: int64

# %%
fuel_econ_sub = fuel_econ.loc[fuel_econ['fuelType'].isin(['Premium Gasoline','Regular Gasoline'])]
sns.countplot(data = fuel_econ_sub, x = 'VClass', hue = 'fuelType')
plt.legend(loc = 6, framealpha = 1,  bbox_to_anchor=(1,.5)) #
plt.xticks(rotation = 15)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text xticklabel objects>)

# %%
fuel_econ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 20 columns):
# id           3929 non-null int64
# make         3929 non-null object
# model        3929 non-null object
# year         3929 non-null int64
# VClass       3929 non-null category
# drive        3929 non-null object
# trans        3929 non-null object
# fuelType     3929 non-null object
# cylinders    3929 non-null int64
# displ        3929 non-null float64
# pv2          3929 non-null int64
# pv4          3929 non-null int64
# city         3929 non-null float64
# UCity        3929 non-null float64
# highway      3929 non-null float64
# UHighway     3929 non-null float64
# comb         3929 non-null float64
# co2          3929 non-null int64
# feScore      3929 non-null int64
# ghgScore     3929 non-null int64
# dtypes: category(1), float64(6), int64(8), object(5)
# memory usage: 587.3+ KB

# %%
fuel_econ.trans.value_counts()
# Out:
# Automatic (S8)                      814
# Automatic (S6)                      739
# Manual 6-spd                        658
# Automatic (AM-S7)                   226
# Automatic 7-spd                     212
# Automatic (variable gear ratios)    178
# Automatic 8-spd                     138
# Manual 5-spd                        126
# Automatic 6-spd                     126
# Automatic (S7)                       98
# Automatic (AM-S6)                    91
# Manual 7-spd                         77
# Automatic (AM6)                      75
# Automatic (AM7)                      63
# Automatic 9-spd                      62
# Automatic (AV-S6)                    43
# Automatic (AV-S7)                    43
# Automatic 5-spd                      33
# Automatic (AM-S8)                    27
# Automatic 4-spd                      25
# Automatic (AV-S8)                    22
# Automatic (S5)                       14
# Automatic (S9)                       14
# Automatic (S10)                      13
# Automatic (A1)                        7
# Automatic (AV-S10)                    3
# Automatic (AM8)                       2
# Name: trans, dtype: int64

# %%
# extracting first value from the trans column.
fuel_econ['trans_type'] = fuel_econ['trans'].apply(lambda x: x.split()[0])
fuel_econ.head()
# Out:
#       id        make           model  year           VClass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
#
#                drive              trans          fuelType  cylinders  displ  \
# 0    All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# 1  Front-Wheel Drive  Automatic (AM-S6)  Premium Gasoline          4    2.0
# 2  Front-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 3    All-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 4  Front-Wheel Drive     Automatic (S6)  Regular Gasoline          4    2.4
#
#       ...      pv4     city    UCity  highway  UHighway     comb  co2  \
# 0     ...        0  16.4596  20.2988  22.5568   30.1798  18.7389  471
# 1     ...        0  21.8706  26.9770  31.0367   42.4936  25.2227  349
# 2     ...        0  17.4935  21.2000  26.5716   35.1000  20.6716  429
# 3     ...        0  16.9415  20.5000  25.2190   33.5000  19.8774  446
# 4     ...       95  24.7726  31.9796  35.5340   51.8816  28.6813  310
#
#    feScore  ghgScore  trans_type
# 0        4         4   Automatic
# 1        6         6   Automatic
# 2        5         5   Automatic
# 3        5         5   Automatic
# 4        8         8   Automatic
#
# [5 rows x 21 columns]

# %%
#countplot
sns.countplot(x = 'VClass', hue = 'trans_type', data = fuel_econ)
plt.xticks(rotation = 90)
plt.show()

# %%
ct_counts = fuel_econ.groupby(['VClass', 'trans_type']).size()
ct_counts
# Out:
# VClass            trans_type
# Minicompact Cars  Automatic     188
#                   Manual        133
# Subcompact Cars   Automatic     502
#                   Manual        171
# Compact Cars      Automatic     784
#                   Manual        338
# Midsize Cars      Automatic     989
#                   Manual        199
# Large Cars        Automatic     605
#                   Manual         20
# dtype: int64

# %%
#converting series to pandas data frame
ct_counts = ct_counts.reset_index(name = 'count')
ct_counts
# Out:
#              VClass trans_type  count
# 0  Minicompact Cars  Automatic    188
# 1  Minicompact Cars     Manual    133
# 2   Subcompact Cars  Automatic    502
# 3   Subcompact Cars     Manual    171
# 4      Compact Cars  Automatic    784
# 5      Compact Cars     Manual    338
# 6      Midsize Cars  Automatic    989
# 7      Midsize Cars     Manual    199
# 8        Large Cars  Automatic    605
# 9        Large Cars     Manual     20

# %%
ct_counts = ct_counts.pivot(index = 'VClass', columns = 'trans_type', values = 'count')
ct_counts
# Out:
# trans_type        Automatic  Manual
# VClass
# Minicompact Cars        188     133
# Subcompact Cars         502     171
# Compact Cars            784     338
# Midsize Cars            989     199
# Large Cars              605      20

# %%
#Adding fmt = 'd' means that annotations will all be formatted as integers instead. 
#You can use fmt = '.0f' if you have any cells with no counts, in order to account for NaNs.
sns.heatmap(ct_counts, annot = True, fmt ='d')

# %% [markdown]
# Faceting

# %%
fuel_econ.comb.describe()
# Out:
# count    3929.000000
# mean       24.791339
# std         6.003246
# min        12.821700
# 25%        20.658100
# 50%        24.000000
# 75%        28.227100
# max        57.782400
# Name: comb, dtype: float64

# %%
bin_edges = np.arange(12, 58+3, 3)
g = sns.FacetGrid(data = fuel_econ, col = 'VClass', sharey = False, col_wrap = 3)
g.map(plt.hist, 'comb', bins = bin_edges)

# %%
# Find the order in which you want to display the Facets
# For each transmission type, find the combined fuel efficiency
group_means = fuel_econ[['trans','comb']].groupby(['trans']).mean()
group_means.head()
# Out:
#                         comb
# trans
# Automatic (A1)     34.677929
# Automatic (AM-S6)  27.770877
# Automatic (AM-S7)  21.572946
# Automatic (AM-S8)  24.119489
# Automatic (AM6)    33.194893

# %%
# Select only the list of transmission type in the decreasing order of combined fuel efficiency
group_order = group_means.sort_values(['comb'], ascending = False).index
group_order
# Out:
# Index(['Automatic (variable gear ratios)', 'Automatic (A1)', 'Automatic (AM6)',
#        'Automatic (AV-S6)', 'Automatic (AV-S7)', 'Manual 5-spd',
#        'Automatic 4-spd', 'Automatic (AM8)', 'Automatic (AV-S10)',
#        'Automatic (AM-S6)', 'Automatic (AV-S8)', 'Manual 6-spd',
#        'Automatic (S6)', 'Automatic 6-spd', 'Automatic (S5)', 'Automatic (S9)',
#        'Automatic (AM-S8)', 'Automatic (AM7)', 'Automatic 9-spd',
#        'Automatic (S7)', 'Automatic (S8)', 'Manual 7-spd', 'Automatic (AM-S7)',
#        'Automatic (S10)', 'Automatic 7-spd', 'Automatic 8-spd',
#        'Automatic 5-spd'],
#       dtype='object', name='trans')

# %%
g = sns.FacetGrid(data = fuel_econ, col =  'trans', col_order = group_order, col_wrap = 7)
g.map(plt.hist, 'comb')

# %%
base_color = sns.color_palette()[0]
sns.barplot(data = fuel_econ, x = 'VClass', y = 'comb', color = base_color)
plt.xticks(rotation = 20)
plt.ylabel('Avg. Combined Fuel Efficiency (mpg)')
# Out:
# Text(0,0.5,'Avg. Combined Fuel Efficiency (mpg)')

# %% [markdown]
# The bar heights indicate the mean value on the numeric variable, with error bars plotted to show the uncertainty in the mean based on variance and sample size.

# %%
sns.barplot(data = fuel_econ, x = 'VClass', y = 'comb', color = base_color, errwidth=0)
plt.xticks(rotation = 20)
plt.ylabel('Avg. Combined Fuel Efficiency (mpg)')
# Out:
# Text(0,0.5,'Avg. Combined Fuel Efficiency (mpg)')

# %%
sns.barplot(data = fuel_econ, x = 'VClass', y = 'comb', color = base_color, ci = 'sd')
plt.xticks(rotation = 20)
plt.ylabel('Avg. Combined Fuel Efficiency (mpg)') # black lines showing the std of the comb
# Out:
# Text(0,0.5,'Avg. Combined Fuel Efficiency (mpg)')

# %%
sns.pointplot(data = fuel_econ, x = 'VClass', y = 'comb', ci = 'sd')
plt.xticks(rotation = 20)
plt.ylabel('Avg. Combined Fuel Efficiency (mpg)')
# Out:
# Text(0,0.5,'Avg. Combined Fuel Efficiency (mpg)')

# %% [markdown]
# The above plots can be useful alternatives to the box plot and violin plot if the data is not conducive to either of those plot types. For example, if the numeric variable is binary in nature, taking values only of 0 or 1, then a box plot or violin plot will not be informative, leaving the adapted bar chart as the best choice for displaying the data.

# %%
#1st plot
plt.figure(figsize=[20,5])
plt.subplot(1,3,1)
sns.violinplot(data = fuel_econ, x = 'VClass', y = 'comb', inner = None, color = base_color)
plt.xticks(rotation = 45);

#2nd plot
plt.subplot(1,3,2)
sns.boxplot(data = fuel_econ, x = 'VClass', y = 'comb', color = base_color);
plt.xticks(rotation = 45)

#3rd plot
plt.subplot(1, 3, 3)
sns.barplot(data=fuel_econ, x='VClass', y='comb', color = base_color)
plt.xticks(rotation = 45);

# %%
# Errorbar
plt.errorbar(data = fuel_econ, x = 'displ', y = 'comb')
plt.ylabel('Avg. Combined Fuel Efficiency (mpg)');

# %%
fuel_econ[['displ', 'comb']].describe()
# Out:
#              displ         comb
# count  3929.000000  3929.000000
# mean      2.950573    24.791339
# std       1.305901     6.003246
# min       0.600000    12.821700
# 25%       2.000000    20.658100
# 50%       2.500000    24.000000
# 75%       3.600000    28.227100
# max       7.000000    57.782400

# %%
bin_edges = np.arange(.6, 7+.2, .2 )
bin_edges
# Out:
# array([ 0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ,  2.2,  2.4,  2.6,
#         2.8,  3. ,  3.2,  3.4,  3.6,  3.8,  4. ,  4.2,  4.4,  4.6,  4.8,
#         5. ,  5.2,  5.4,  5.6,  5.8,  6. ,  6.2,  6.4,  6.6,  6.8,  7. ])

# %%
bin_c = bin_edges[:-1] + 0.1
bin_c
# Out:
# array([ 0.7,  0.9,  1.1,  1.3,  1.5,  1.7,  1.9,  2.1,  2.3,  2.5,  2.7,
#         2.9,  3.1,  3.3,  3.5,  3.7,  3.9,  4.1,  4.3,  4.5,  4.7,  4.9,
#         5.1,  5.3,  5.5,  5.7,  5.9,  6.1,  6.3,  6.5,  6.7,  6.9])

# %%
displ_bin = pd.cut(fuel_econ['displ'], bin_edges, include_lowest = True)
displ_bin.head()
# Out:
# 0    (3.6, 3.8]
# 1    (1.8, 2.0]
# 2    (3.4, 3.6]
# 3    (3.4, 3.6]
# 4    (2.2, 2.4]
# Name: displ, dtype: category
# Categories (32, interval[float64]): [(0.599, 0.8] < (0.8, 1.0] < (1.0, 1.2] < (1.2, 1.4] ... (6.2, 6.4] < (6.4, 6.6] < (6.6, 6.8] < (6.8, 7.0]]

# %%
# For the points in each bin, we compute the mean and standard error of the mean.
comb_mean = fuel_econ['comb'].groupby(displ_bin).mean()
comb_mean.head()
# Out:
# displ
# (0.599, 0.8]    37.057583
# (0.8, 1.0]      33.469158
# (1.0, 1.2]      35.838600
# (1.2, 1.4]      31.964468
# (1.4, 1.6]      30.489490
# Name: comb, dtype: float64

# %%
comb_std = fuel_econ['comb'].groupby(displ_bin).std()
comb_std.head()
# Out:
# displ
# (0.599, 0.8]    2.648632
# (0.8, 1.0]      1.448621
# (1.0, 1.2]      2.401971
# (1.2, 1.4]      3.465692
# (1.4, 1.6]      5.059187
# Name: comb, dtype: float64

# %%
#plotting error bar using above calculated values
plt.errorbar(x = bin_c, y = comb_mean, yerr = comb_std)
plt.ylabel('Avg. Combined Fuel Efficiency (mpg)');

# %% [markdown]
# Task 1:
#
# Plot the distribution of combined fuel mileage (column 'comb', in miles per gallon) by manufacturer (column 'make'), for all manufacturers with at least eighty cars in the dataset. Consider which manufacturer order will convey the most information when constructing your final plot.

# %%
Threshold = 80
make_freq = fuel_econ['make'].value_counts()
idx = np.sum(make_freq > Threshold)
idx
# Out:
# 18

# %%
most_makes = make_freq.index[:idx]
most_makes
# Out:
# Index(['BMW', 'Mercedes-Benz', 'Porsche', 'Ford', 'Chevrolet', 'MINI', 'Audi',
#        'Volkswagen', 'Hyundai', 'Dodge', 'Lexus', 'Kia', 'Cadillac', 'Toyota',
#        'Infiniti', 'Honda', 'Jaguar', 'Mazda'],
#       dtype='object')

# %%
fuel_econ_sub = fuel_econ.loc[fuel_econ['make'].isin(most_makes)]
fuel_econ_sub
# Out:
#          id           make                           model  year  \
# 1     32205     Volkswagen                              CC  2013
# 2     32206     Volkswagen                              CC  2013
# 3     32207     Volkswagen                      CC 4motion  2013
# 4     32208      Chevrolet                  Malibu eAssist  2013
# 5     32209          Lexus                          GS 350  2013
# 6     32210          Lexus                      GS 350 AWD  2013
# 7     32214        Hyundai                   Genesis Coupe  2013
# 8     32215        Hyundai                   Genesis Coupe  2013
# 9     32216        Hyundai                   Genesis Coupe  2013
# 10    32217        Hyundai                   Genesis Coupe  2013
# 11    32218     Volkswagen                              CC  2013
# 15    32231          Mazda                               6  2013
# 16    32232           Ford                      Taurus AWD  2013
# 17    32233           Ford                      Taurus AWD  2013
# 18    32234           Ford                  Taurus AWD FFV  2013
# 19    32235           Ford                      Taurus FWD  2013
# 20    32244           Ford                         Mustang  2013
# 21    32245           Ford                         Mustang  2013
# 22    32246           Ford                         Mustang  2013
# 23    32247           Ford                         Mustang  2013
# 24    32248           Ford             Mustang Convertible  2013
# 25    32249            Kia                             Rio  2013
# 26    32250            Kia                             Rio  2013
# 27    32251            Kia                         Rio Eco  2013
# 28    32252        Hyundai                         Elantra  2013
# 29    32253        Hyundai                         Elantra  2013
# 30    32254        Hyundai                    Elantra Blue  2013
# 31    32255        Hyundai                   Elantra Coupe  2013
# 32    32256        Hyundai                   Elantra Coupe  2013
# 33    32257          Mazda                               6  2013
# ...     ...            ...                             ...   ...
# 3898  39789           Ford                      Fiesta FWD  2018
# 3899  39790           Ford                      Fiesta FWD  2018
# 3900  39791           Ford                   Fiesta ST FWD  2018
# 3902  39813         Toyota                              86  2018
# 3903  39814         Toyota                              86  2018
# 3904  39815          Lexus                            RC F  2018
# 3905  39816          Lexus                          RC 300  2018
# 3906  39817          Lexus                      RC 300 AWD  2018
# 3907  39818          Lexus                          RC 350  2018
# 3908  39819          Lexus                      RC 350 AWD  2018
# 3909  39820            BMW                     540d xDrive  2018
# 3910  39821            BMW                              M5  2018
# 3911  39822            Kia                        Optima S  2018
# 3912  39832     Volkswagen                            Golf  2018
# 3913  39834            BMW   i3 (94Ah) with Range Extender  2018
# 3914  39835            BMW  i3s (94Ah) with Range Extender  2018
# 3915  39844         Jaguar                     XF (296 Hp)  2018
# 3916  39845          Mazda                               6  2018
# 3917  39846          Mazda                               6  2018
# 3918  39847          Mazda                               6  2018
# 3919  39853  Mercedes-Benz                           C350e  2018
# 3920  39856     Volkswagen                            Golf  2018
# 3921  39865            BMW                    X2 xDrive28i  2018
# 3922  39866          Lexus                         LS 500h  2018
# 3923  39867          Lexus                     LS 500h AWD  2018
# 3924  39882         Toyota                     Prius Prime  2018
# 3925  39898        Hyundai                   Sonata Hybrid  2018
# 3926  39899        Hyundai                Sonata Hybrid SE  2018
# 3927  39900          Lexus                          LS 500  2018
# 3928  39901          Lexus                      LS 500 AWD  2018
#
#                 VClass              drive                             trans  \
# 1         Compact Cars  Front-Wheel Drive                 Automatic (AM-S6)
# 2         Compact Cars  Front-Wheel Drive                    Automatic (S6)
# 3         Compact Cars    All-Wheel Drive                    Automatic (S6)
# 4         Midsize Cars  Front-Wheel Drive                    Automatic (S6)
# 5         Midsize Cars   Rear-Wheel Drive                    Automatic (S6)
# 6         Midsize Cars    All-Wheel Drive                    Automatic (S6)
# 7      Subcompact Cars   Rear-Wheel Drive                   Automatic 8-spd
# 8      Subcompact Cars   Rear-Wheel Drive                      Manual 6-spd
# 9      Subcompact Cars   Rear-Wheel Drive                   Automatic 8-spd
# 10     Subcompact Cars   Rear-Wheel Drive                      Manual 6-spd
# 11        Compact Cars  Front-Wheel Drive                      Manual 6-spd
# 15        Midsize Cars  Front-Wheel Drive                    Automatic (S6)
# 16          Large Cars    All-Wheel Drive                    Automatic (S6)
# 17          Large Cars    All-Wheel Drive                    Automatic (S6)
# 18          Large Cars    All-Wheel Drive                    Automatic (S6)
# 19          Large Cars  Front-Wheel Drive                    Automatic (S6)
# 20     Subcompact Cars   Rear-Wheel Drive                   Automatic 6-spd
# 21     Subcompact Cars   Rear-Wheel Drive                      Manual 6-spd
# 22     Subcompact Cars   Rear-Wheel Drive                   Automatic 6-spd
# 23     Subcompact Cars   Rear-Wheel Drive                      Manual 6-spd
# 24     Subcompact Cars   Rear-Wheel Drive                   Automatic 6-spd
# 25        Compact Cars  Front-Wheel Drive                   Automatic 6-spd
# 26        Compact Cars  Front-Wheel Drive                      Manual 6-spd
# 27        Compact Cars  Front-Wheel Drive                   Automatic 6-spd
# 28        Midsize Cars  Front-Wheel Drive                   Automatic 6-spd
# 29        Midsize Cars  Front-Wheel Drive                      Manual 6-spd
# 30        Midsize Cars  Front-Wheel Drive                   Automatic 6-spd
# 31        Midsize Cars  Front-Wheel Drive                   Automatic 6-spd
# 32        Midsize Cars  Front-Wheel Drive                      Manual 6-spd
# 33        Midsize Cars  Front-Wheel Drive                    Automatic (S5)
# ...                ...                ...                               ...
# 3898   Subcompact Cars  Front-Wheel Drive                 Automatic (AM-S6)
# 3899   Subcompact Cars  Front-Wheel Drive                      Manual 5-spd
# 3900      Compact Cars  Front-Wheel Drive                      Manual 6-spd
# 3902  Minicompact Cars   Rear-Wheel Drive                    Automatic (S6)
# 3903  Minicompact Cars   Rear-Wheel Drive                      Manual 6-spd
# 3904   Subcompact Cars   Rear-Wheel Drive                    Automatic (S8)
# 3905   Subcompact Cars   Rear-Wheel Drive                    Automatic (S8)
# 3906   Subcompact Cars    All-Wheel Drive                    Automatic (S6)
# 3907   Subcompact Cars   Rear-Wheel Drive                    Automatic (S8)
# 3908   Subcompact Cars    All-Wheel Drive                    Automatic (S6)
# 3909      Midsize Cars    All-Wheel Drive                    Automatic (S8)
# 3910      Midsize Cars    All-Wheel Drive                    Automatic (S8)
# 3911        Large Cars  Front-Wheel Drive                    Automatic (S6)
# 3912      Compact Cars  Front-Wheel Drive                    Automatic (S6)
# 3913   Subcompact Cars   Rear-Wheel Drive                    Automatic (A1)
# 3914   Subcompact Cars     Automatic (A1)                    Automatic (A1)
# 3915      Midsize Cars   Rear-Wheel Drive                    Automatic (S8)
# 3916      Midsize Cars  Front-Wheel Drive                      Manual 6-spd
# 3917      Midsize Cars  Front-Wheel Drive                    Automatic (S6)
# 3918      Midsize Cars  Front-Wheel Drive                    Automatic (S6)
# 3919      Compact Cars   Rear-Wheel Drive                   Automatic 7-spd
# 3920      Compact Cars  Front-Wheel Drive                      Manual 5-spd
# 3921      Midsize Cars    All-Wheel Drive                    Automatic (S8)
# 3922      Midsize Cars   Rear-Wheel Drive                Automatic (AV-S10)
# 3923      Midsize Cars    All-Wheel Drive                Automatic (AV-S10)
# 3924      Midsize Cars  Front-Wheel Drive  Automatic (variable gear ratios)
# 3925      Midsize Cars  Front-Wheel Drive                   Automatic (AM6)
# 3926      Midsize Cars  Front-Wheel Drive                   Automatic (AM6)
# 3927      Midsize Cars   Rear-Wheel Drive                   Automatic (S10)
# 3928      Midsize Cars    All-Wheel Drive                   Automatic (S10)
#
#               fuelType  cylinders  displ     ...      pv4     city    UCity  \
# 1     Premium Gasoline          4    2.0     ...        0  21.8706  26.9770
# 2     Premium Gasoline          6    3.6     ...        0  17.4935  21.2000
# 3     Premium Gasoline          6    3.6     ...        0  16.9415  20.5000
# 4     Regular Gasoline          4    2.4     ...       95  24.7726  31.9796
# 5     Premium Gasoline          6    3.5     ...       99  19.4325  24.1499
# 6     Premium Gasoline          6    3.5     ...       99  18.5752  23.5261
# 7     Premium Gasoline          4    2.0     ...        0  17.4460  21.7946
# 8     Premium Gasoline          4    2.0     ...        0  20.6741  26.2000
# 9     Premium Gasoline          6    3.8     ...        0  16.4675  20.4839
# 10    Premium Gasoline          6    3.8     ...        0  18.1909  22.8000
# 11    Premium Gasoline          4    2.0     ...        0  20.8232  25.7303
# 15    Regular Gasoline          6    3.7     ...      102  17.7357  21.7000
# 16    Regular Gasoline          6    3.5     ...      102  18.1170  22.7000
# 17    Regular Gasoline          6    3.5     ...      102  17.1523  21.4000
# 18    Regular Gasoline          6    3.5     ...      102  18.1170  22.7000
# 19    Regular Gasoline          6    3.5     ...      102  19.3144  24.3290
# 20    Regular Gasoline          6    3.7     ...        0  19.2053  24.1798
# 21    Regular Gasoline          6    3.7     ...        0  18.5595  23.3000
# 22    Regular Gasoline          8    5.0     ...        0  17.5859  21.9829
# 23    Regular Gasoline          8    5.0     ...        0  15.5004  19.1995
# 24    Regular Gasoline          6    3.7     ...        0  19.2257  24.2077
# 25    Regular Gasoline          4    1.6     ...       88  28.0000  38.7000
# 26    Regular Gasoline          4    1.6     ...       88  29.0000  39.5000
# 27    Regular Gasoline          4    1.6     ...       88  30.0000  40.7278
# 28    Regular Gasoline          4    1.8     ...       96  28.0000  37.8169
# 29    Regular Gasoline          4    1.8     ...       96  28.0000  38.2000
# 30    Regular Gasoline          4    1.8     ...       96  28.0000  38.6483
# 31    Regular Gasoline          4    1.8     ...        0  27.0000  35.9599
# 32    Regular Gasoline          4    1.8     ...        0  28.0000  38.0000
# 33    Regular Gasoline          4    2.5     ...      102  21.3496  27.1379
# ...                ...        ...    ...     ...      ...      ...      ...
# 3898  Regular Gasoline          4    1.6     ...       85  27.0000  36.1000
# 3899  Regular Gasoline          4    1.6     ...       85  27.3743  35.7619
# 3900  Regular Gasoline          4    1.6     ...        0  26.0325  33.8000
# 3902  Premium Gasoline          4    2.0     ...        0  23.8080  30.6000
# 3903  Premium Gasoline          4    2.0     ...        0  20.8906  26.5000
# 3904  Premium Gasoline          8    5.0     ...        0  16.0000  20.7000
# 3905  Premium Gasoline          4    2.0     ...        0  22.1809  28.3000
# 3906  Premium Gasoline          6    3.5     ...        0  18.0000  24.0125
# 3907  Premium Gasoline          6    3.5     ...        0  19.8039  25.0000
# 3908  Premium Gasoline          6    3.5     ...        0  18.0000  24.0125
# 3909            Diesel          6    3.0     ...       99  25.9806  33.7245
# 3910  Premium Gasoline          8    4.4     ...       99  14.7050  18.1512
# 3911  Regular Gasoline          4    2.4     ...      105  22.7666  29.1241
# 3912  Regular Gasoline          4    1.8     ...        0  24.4816  30.3056
# 3913  Premium Gasoline          2    0.6     ...       84  35.8077  48.6702
# 3914  Premium Gasoline          2    0.6     ...       84  35.8077  48.6702
# 3915  Premium Gasoline          4    2.0     ...       97  23.4563  30.0943
# 3916  Regular Gasoline          4    2.5     ...      100  24.0885  31.0000
# 3917  Regular Gasoline          4    2.5     ...      100  26.0089  33.7657
# 3918  Regular Gasoline          4    2.5     ...      100  23.4563  30.1000
# 3919  Premium Gasoline          4    2.0     ...       91  28.5000  37.4000
# 3920  Regular Gasoline          4    1.8     ...        0  25.2861  31.3000
# 3921  Premium Gasoline          4    2.0     ...        0  21.4659  27.3000
# 3922  Premium Gasoline          6    3.5     ...        0  25.0325  33.7893
# 3923  Premium Gasoline          6    3.5     ...        0  22.9443  30.6460
# 3924  Regular Gasoline          4    1.8     ...        0  55.2206  78.8197
# 3925  Regular Gasoline          4    2.0     ...      106  39.0000  55.9000
# 3926  Regular Gasoline          4    2.0     ...      106  40.0000  56.0000
# 3927  Premium Gasoline          6    3.4     ...        0  19.2200  24.2000
# 3928  Premium Gasoline          6    3.4     ...        0  18.0431  22.6000
#
#       highway  UHighway     comb  co2  feScore  ghgScore  trans_type
# 1     31.0367   42.4936  25.2227  349        6         6   Automatic
# 2     26.5716   35.1000  20.6716  429        5         5   Automatic
# 3     25.2190   33.5000  19.8774  446        5         5   Automatic
# 4     35.5340   51.8816  28.6813  310        8         8   Automatic
# 5     28.2234   38.5000  22.6002  393        6         6   Automatic
# 6     26.3573   36.2109  21.4213  412        5         5   Automatic
# 7     26.6295   37.6731  20.6507  432        5         5   Automatic
# 8     29.2741   41.8000  23.8235  375        6         6      Manual
# 9     24.5605   34.4972  19.3344  461        4         4   Automatic
# 10    26.7761   37.9000  21.2581  420        5         5      Manual
# 11    31.7255   43.9687  24.6323  360        6         6      Manual
# 15    26.6826   34.6000  20.8874  463        5         5   Automatic
# 16    25.5432   36.0000  20.8440  426        5         5   Automatic
# 17    25.0000   35.6000  20.0543  446        5         5   Automatic
# 18    25.5432   36.0000  20.8440  426        5         5   Automatic
# 19    28.1465   40.0311  22.4901  395        6         6   Automatic
# 20    30.4395   43.6431  23.0301  386        6         6   Automatic
# 21    28.5740   40.7000  22.0347  403        5         5      Manual
# 22    24.9515   35.0939  20.2798  438        5         5   Automatic
# 23    25.2823   35.6000  18.7681  473        4         4      Manual
# 24    29.0745   41.4859  22.6834  392        6         6   Automatic
# 25    36.0000   56.5000  31.0000  291        8         8   Automatic
# 26    37.0000   56.8000  32.0000  283        8         8      Manual
# 27    36.0000   56.9550  32.0000  279        8         8   Automatic
# 28    38.0000   56.5000  32.0000  284        8         8   Automatic
# 29    38.0000   56.5000  32.0000  284        8         8      Manual
# 30    38.0000   57.0799  32.0000  285        8         8   Automatic
# 31    37.0000   55.6829  31.0000  294        8         8   Automatic
# 32    38.0000   56.6000  32.0000  285        8         8      Manual
# 33    29.7270   42.5144  24.4503  363        6         6   Automatic
# ...       ...       ...      ...  ...      ...       ...         ...
# 3898  36.8746   54.1000  31.1253  286        7         7   Automatic
# 3899  34.9655   50.9473  30.3383  293        7         7      Manual
# 3900  33.2185   48.1000  28.8400  308        6         6      Manual
# 3902  32.2893   46.6000  26.9993  328        6         6   Automatic
# 3903  28.3824   40.4000  23.7065  373        5         5      Manual
# 3904  25.0000   34.8000  19.0000  465        3         3   Automatic
# 3905  32.1028   46.3000  25.7642  345        5         5   Automatic
# 3906  24.0000   36.2000  21.0000  422        4         4   Automatic
# 3907  27.9986   39.8000  22.8079  388        5         5   Automatic
# 3908  24.0000   36.2000  21.0000  422        4         4   Automatic
# 3909  36.4503   53.3955  29.8372  341        7         5   Automatic
# 3910  20.9265   29.0277  16.9762  521        3         3   Automatic
# 3911  32.4681   46.8878  26.3034  340        5         5   Automatic
# 3912  32.7773   46.6913  27.6282  320        6         6   Automatic
# 3913  33.0983   47.1695  34.5356   29       10        10   Automatic
# 3914  33.0983   47.1695  34.5356   29       10        10   Automatic
# 3915  31.4791   45.2753  26.4949  335        5         5   Automatic
# 3916  33.0000   48.6000  27.0000  328        6         6      Manual
# 3917  34.9158   50.8657  29.3817  302        6         6   Automatic
# 3918  31.2288   44.9000  26.4147  335        5         5   Automatic
# 3919  32.2000   46.5000  30.1000  215        8         9   Automatic
# 3920  33.9494   48.6000  28.5664  309        6         6      Manual
# 3921  30.5383   43.8000  24.7785  357        5         5   Automatic
# 3922  33.2414   46.5000  28.1621  314        6         6   Automatic
# 3923  30.9804   41.7990  25.9764  340        5         5   Automatic
# 3924  53.0000   73.6525  54.4329   78       10        10   Automatic
# 3925  44.3066   64.0000  41.0000  217        9         9   Automatic
# 3926  46.0000   64.0000  42.0000  212        9         9   Automatic
# 3927  30.2863   43.4000  23.0021  387        5         5   Automatic
# 3928  27.0000   39.3000  21.3945  417        4         4   Automatic
#
# [3208 rows x 21 columns]

# %%
make_mean = fuel_econ_sub.groupby('make').mean()
make_mean.head()
# Out:
#                      id         year  cylinders     displ        pv2  \
# make
# Audi       35835.398010  2015.532338   5.512438  2.751741  25.781095
# BMW        35953.648184  2015.493308   5.973231  3.083748  35.441683
# Cadillac   36052.110169  2015.584746   5.474576  3.243220  24.398305
# Chevrolet  35903.301887  2015.476415   4.886792  2.599528  19.740566
# Dodge      35907.100000  2015.278571   6.285714  4.225714  32.228571
#
#                  pv4       city      UCity    highway   UHighway       comb  \
# make
# Audi       48.786070  20.426925  25.652045  29.389482  40.513205  23.639240
# BMW        55.269598  19.862614  25.157074  28.649093  40.927519  23.004798
# Cadillac   93.983051  18.845043  24.039474  26.939762  38.256114  21.773203
# Chevrolet  67.037736  23.955976  31.080558  33.017294  47.937314  27.224809
# Dodge      41.035714  18.516134  23.345414  27.948863  39.730484  21.812190
#
#                   co2   feScore  ghgScore
# make
# Audi       384.676617  5.432836  5.402985
# BMW        394.885277  5.221797  5.214149
# Cadillac   408.686441  4.915254  4.932203
# Chevrolet  343.957547  6.386792  6.353774
# Dodge      424.164286  4.878571  4.878571

# %%
comb_order = make_mean.sort_values('comb', ascending = False).index
comb_order
# Out:
# Index(['Toyota', 'Honda', 'Mazda', 'Hyundai', 'Kia', 'MINI', 'Volkswagen',
#        'Chevrolet', 'Ford', 'Lexus', 'Audi', 'BMW', 'Infiniti', 'Dodge',
#        'Cadillac', 'Mercedes-Benz', 'Porsche', 'Jaguar'],
#       dtype='object', name='make')

# %%
fuel_econ_sub.comb.describe()
# Out:
# count    3208.000000
# mean       25.198091
# std         5.956012
# min        13.858000
# 25%        21.000000
# 50%        24.391000
# 75%        28.530925
# max        57.782400
# Name: comb, dtype: float64

# %%
g = sns.FacetGrid(data = fuel_econ_sub, col = 'make', col_order = comb_order, col_wrap = 6, size = 2)
g.map(plt.hist, 'comb', bins = np.arange(13, 58+2,2))
g.set_titles('{col_name}')

# %% [markdown]
# Task 2:
#
# Continuing on from the previous task, plot the mean fuel efficiency for each manufacturer with at least 80 cars in the dataset.

# %%
sns.barplot(data = fuel_econ_sub, y = 'make', x = 'comb', color = base_color, ci = 'sd')
plt.xlabel('Average Combined Fuel Eff. (mpg)')
# Out:
# Text(0.5,0,'Average Combined Fuel Eff. (mpg)')
